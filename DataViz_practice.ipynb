# %%
from pandas import read_csv
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
HRData = read_csv('C:/Users/aanal/Documents/HRD.csv')
HRData.head(10)
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
# 5         Anderson, Linda    10002          0                0         0
# 6           Andreola, Colby  10194          0                0         0
# 7               Athwal, Sam  10062          0                4         1
# 8          Bachiochi, Linda  10114          0                0         0
# 9        Bacong, Alejandro   10250          0                2         1
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# ...

# %%
# checking the column names
coulmnNames = HRData.columns
print('column Names = {}'.format(coulmnNames))
# Out:
# column Names = Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
# checking the data types of the data set
HRData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %%
HRData['DOB'].head()
# Out:
# 0    07/10/83
# 1    05/05/75
# 2    09/19/88
# 3    09/27/88
# 4    09/08/89
# Name: DOB, dtype: object

# %%
# converting DOB from object to datetime data type
HRData['DOB'] = pd.to_datetime(HRData['DOB'])
HRData['DateofHire'] = pd.to_datetime(HRData['DateofHire'])
HRData['DateofTermination'] = pd.to_datetime(HRData['DateofTermination'])

# %%
HRData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %%
# reviewing the statstical summery
HRData.describe()
# Out:
#               EmpID   MarriedID  MaritalStatusID    GenderID  EmpStatusID  \
# count    311.000000  311.000000       311.000000  311.000000   311.000000
# mean   10156.000000    0.398714         0.810289    0.434084     2.392283
# std       89.922189    0.490423         0.943239    0.496435     1.794383
# min    10001.000000    0.000000         0.000000    0.000000     1.000000
# 25%    10078.500000    0.000000         0.000000    0.000000     1.000000
# 50%    10156.000000    0.000000         1.000000    0.000000     1.000000
# 75%    10233.500000    1.000000         1.000000    1.000000     5.000000
# max    10311.000000    1.000000         4.000000    1.000000     5.000000
#
#            DeptID  PerfScoreID  FromDiversityJobFairID         Salary  \
# count  311.000000   311.000000              311.000000     311.000000
# mean     4.610932     2.977492                0.093248   69020.684887
# std      1.083487     0.587072                0.291248   25156.636930
# ...

# %%
# checking the missing values
HRData.isna().sum()
# Out:
# Employee_Name                   0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ...

# %% [markdown]
# ## Histogram and distribution using matplot lib and oop method

# %%
# matplot lib method
# salary
plt.figure(figsize=(5,3))
plt.hist(HRData['Salary'], bins=20, color='Blue', edgecolor='white')
plt.legend(labels=['salary'])
plt.title('Dirtibution of salary', fontsize = 16)
plt.xlabel('salary', fontsize = 13)
plt.ylabel('Frequency', fontsize = 13)
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=10)
plt.grid(alpha=0.3) # alpha is representation of tranperency, 1 being opque and 0 being transperent
plt.show()

# EmpSatisfaction
plt.figure(figsize=(5,3))
plt.hist(HRData['EmpSatisfaction'], bins=20, color='black', edgecolor='white')
plt.legend(labels=['EmpSatisfaction'])
plt.title('Dirtibution of EmpSatisfaction', fontsize = 16)
plt.xlabel('EmpSatisfaction', fontsize = 13)
plt.ylabel('Frequency', fontsize = 13)
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=10)
plt.grid(alpha=0.3) # alpha is representation of tranperency, 1 being opque and 0 being transperent
plt.show()

# EngagementSurvey
plt.figure(figsize=(5,3))
plt.hist(HRData['EngagementSurvey'], bins=20, color='skyblue', edgecolor='white')
plt.legend(labels=['EngagementSurvey'])
plt.title('Dirtibution of EngagementSurvey', fontsize = 16)
plt.xlabel('EngagementSurvey', fontsize = 13)
plt.ylabel('Frequency', fontsize = 13)
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=10)
plt.grid(alpha=0.3) # alpha is representation of tranperency, 1 being opque and 0 being transperent
plt.show()

# %%
# oop method
# Set up subplots with 1 row and 3 columns
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Plot 1: Distribution of Salary
axes[0].hist(HRData['Salary'], bins=20, color='blue', edgecolor='white')
axes[0].set_title('Distribution of Salary', fontsize=16)
axes[0].set_xlabel('Salary', fontsize=13)
axes[0].set_ylabel('Frequency', fontsize=13)
axes[0].tick_params(axis='x', labelsize=10, rotation=45)
axes[0].tick_params(axis='y', labelsize=10)
axes[0].grid(alpha=0.3)

# Plot 2: Distribution of EmpSatisfaction
axes[1].hist(HRData['EmpSatisfaction'], bins=20, color='black', edgecolor='white')
axes[1].set_title('Distribution of EmpSatisfaction', fontsize=16)
axes[1].set_xlabel('EmpSatisfaction', fontsize=13)
axes[1].set_ylabel('Frequency', fontsize=13)
axes[1].tick_params(axis='x', labelsize=10, rotation=45)
axes[1].tick_params(axis='y', labelsize=10)
axes[1].grid(alpha=0.3)

# Plot 3: Distribution of EngagementSurvey
axes[2].hist(HRData['EngagementSurvey'], bins=20, color='skyblue', edgecolor='white')
axes[2].set_title('Distribution of EngagementSurvey', fontsize=16)
axes[2].set_xlabel('EngagementSurvey', fontsize=13)
axes[2].set_ylabel('Frequency', fontsize=13)
axes[2].tick_params(axis='x', labelsize=10, rotation=45)
axes[2].tick_params(axis='y', labelsize=10)
axes[2].grid(alpha=0.3)

# Adjust layout
plt.tight_layout()

# Display the plots
plt.show()

# %% [markdown]
# ## Box Plots for Categorical Variables

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(7,3))
sns.boxplot(x='MarriedID', y='Salary', data=HRData, palette='Set3')
plt.title('Number of marriages', fontsize = 16)
plt.xlabel('MarriedID', fontsize = 13)
plt.ylabel('Salary', fontsize = 13)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# ## Correlation Heatmap

# %%
# corrilation matrix
corr_matrix = HRData.corr()
print(corr_matrix)
# Out:
#                            EmpID  MarriedID  MaritalStatusID  GenderID  \
# EmpID                   1.000000   0.048058        -0.043851  0.035914
# MarriedID               0.048058   1.000000         0.164044 -0.024199
# MaritalStatusID        -0.043851   0.164044         1.000000 -0.030236
# GenderID                0.035914  -0.024199        -0.030236  1.000000
# EmpStatusID             0.073750   0.085619         0.114630 -0.032440
# DeptID                  0.107406  -0.119932         0.012768 -0.038838
# PerfScoreID            -0.691348  -0.058362         0.044693 -0.054915
# FromDiversityJobFairID  0.046805  -0.012708         0.041117  0.031493
# Salary                 -0.115319   0.026165        -0.070291  0.056097
# Termd                   0.092389   0.077028         0.099367 -0.015741
# PositionID             -0.036488  -0.027334         0.021923 -0.081612
# Zip                     0.026858  -0.041147         0.010620  0.048539
# ...

# %%
plt.figure(figsize=(9, 9))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".1f", linewidths=0.2)

# Customize the plot
plt.title('Correlation Heatmap of Numerical Variables', fontsize=16)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Display the plot
plt.show()

# %% [markdown]
# ##  pair plot

# %%
selected_vars = ['Salary', 'EngagementSurvey', 'EmpSatisfaction', 'SpecialProjectsCount']

# Set up the pair plot
sns.set(style="ticks") # ticks = mark the ticks on the graph
sns.pairplot(HRData[selected_vars], height=2, markers='s', diag_kind='kde', aspect=1.1) 
# markers: s = squear, o = circle, d = dimond, +, *, x
# diag_kind: kde =  Kernel Density Estimate, hist and None- None will not plot anytghing on the graph

# Customize the plot
plt.suptitle('Pair Plot of Selected Numerical Variables', x=0.5, y=1.02, fontsize=16)
plt.show()

# %% [markdown]
# ## bar plot for Categorical Variables

# %%
plt.figure(figsize=(7, 3))
ax = sns.countplot(x='DeptID', data=HRData, palette='viridis')

# this code is for the putting the value over the bar for y parameter
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 2), textcoords='offset points', fontsize=10)
    
plt.title('Number of Employees in Each Department', fontsize=16)
plt.xlabel('Department ID', fontsize=14)
plt.ylabel('Number of Employees', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
plt.figure(figsize=(7, 3))
plt.scatter(HRData['Salary'], HRData['DaysLateLast30'], color='blue', alpha=0.5)
plt.title('Scatter Plot: Salary vs. DaysLateLast30', fontsize=16)
plt.xlabel('Salary', fontsize=14)
plt.ylabel('Days Late Last 30', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# ## Pie Charts

# %%
marital_status_counts = HRData['MarriedID'].value_counts()

# Map values to labels
marital_status_labels = {0: 'Single', 1: 'Married'}
marital_status_counts.index = marital_status_counts.index.map(marital_status_labels)

plt.figure(figsize=(8, 8))
pie, texts, autotexts = plt.pie(marital_status_counts, autopct='%1.1f%%', colors=['skyblue', 'lightcoral'], startangle=0)

# Add legend annotations
legend_labels = ['Single', 'Married']
legend_colors = ['skyblue', 'lightcoral']
legend_patches = [plt.Line2D([0], [0], marker='*', color='k', label=label, markersize=15, markerfacecolor=color) for label, color in zip(legend_labels, legend_colors)]
plt.legend(handles=legend_patches, loc='upper right')

# Add text annotations
for text, autotext, label in zip(texts, autotexts, marital_status_counts.index):
    text.set_text(f'{label}: {text.get_text()}')

plt.title('Distribution of Employees by Marital Status', fontsize=16)

plt.show()

# %% [markdown]
# ## Time Series Analysis

# %%
HRData['LastPerformanceReview_Date'] = pd.to_datetime(HRData['LastPerformanceReview_Date'])
plt.figure(figsize=(12, 6))
plt.plot(HRData['LastPerformanceReview_Date'], HRData['PerformanceScore'], marker='s', linestyle='-', color='lightcoral')
plt.title('Performance Score Over Time', fontsize=16)
plt.xlabel('Date of Last Performance Review', fontsize=14)
plt.ylabel('Performance Score', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# ## Employee Satisfaction Analysis

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(x='EmpSatisfaction', data=HRData, palette='Blues')
plt.title('Distribution of Employee Satisfaction Scores', fontsize=16)
plt.xlabel('Employee Satisfaction', fontsize=14)
plt.show()

# %% [markdown]
# https://www.linkedin.com/learning/certificates/6cfbc9da03f83f6862aac8faa95aa2f1593b344bc43e8f3c29f8a4b0446e4308
# https://www.linkedin.com/learning/certificates/ee6af2ff7e326a455c68f01775cf4196c09b00c5565663da8dfed4d6f8889bd9
